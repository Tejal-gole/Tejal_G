# %% [markdown]
# <a href="https://colab.research.google.com/github/Tejal-gole/Tejal_G/blob/master/person_yolov3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
# !nvidia-smi
# Out:
# Fri May 29 04:18:22 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 440.82       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   37C    P8     9W /  70W |      0MiB / 15079MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# ...

# %%
#clone darknet repository 
import os
os.environ['PATH'] += ':/usr/local/cuda/bin'
# !rm -fr darknet
# !git clone https://github.com/AlexeyAB/darknet/
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 8, done.
# remote: Counting objects: 100% (8/8), done.
# remote: Compressing objects: 100% (8/8), done.
# remote: Total 13567 (delta 1), reused 1 (delta 0), pack-reused 13559
# Receiving objects: 100% (13567/13567), 12.21 MiB | 24.86 MiB/s, done.
# Resolving deltas: 100% (9256/9256), done.

# %%
# !apt install gcc-5 g++-5 -y
# !ln -s /usr/bin/gcc-5 /usr/local/cuda/bin/gcc 
# !ln -s /usr/bin/g++-5 /usr/local/cuda/bin/g++
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   cpp-5 gcc-5-base libasan2 libgcc-5-dev libisl15 libmpx0 libstdc++-5-dev
# Suggested packages:
#   gcc-5-locales g++-5-multilib gcc-5-doc libstdc++6-5-dbg gcc-5-multilib
#   libgcc1-dbg libgomp1-dbg libitm1-dbg libatomic1-dbg libasan2-dbg
#   liblsan0-dbg libtsan0-dbg libubsan0-dbg libcilkrts5-dbg libmpx0-dbg
#   libquadmath0-dbg libstdc++-5-doc
# The following NEW packages will be installed:
#   cpp-5 g++-5 gcc-5 gcc-5-base libasan2 libgcc-5-dev libisl15 libmpx0
#   libstdc++-5-dev
# 0 upgraded, 9 newly installed, 0 to remove and 31 not upgraded.
# Need to get 29.1 MB of archives.
# After this operation, 100 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 gcc-5-base amd64 5.5.0-12ubuntu1 [17.1 kB]
# ...

# %%
# go to the darknet folder, enable GPU, then compile the entire thing
# %cd darknet
# !sed -i 's/GPU=0/GPU=1/g' Makefile
# !sed -i 's/OPENCV=0/OPENCV=1/g' Makefile
# !make
# Out:
# /content/darknet
# mkdir -p ./obj/
# mkdir -p backup
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:910:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#                  float rgb[3];
#                        ^
# ./src/image_opencv.cpp: In function ‘void cv_draw_object(image, float*, int, int, int*, float*, int*, int, char**)’:
# ./src/image_opencv.cpp:1391:14: warning: unused variable ‘buff’ [-Wunused-variable]
#          char buff[100];
#               ^
# ...

# %%
# !wget https://pjreddie.com/media/files/yolov3.weights
# !chmod a+x ./darknet
# Out:
# --2020-05-27 07:00:09--  https://pjreddie.com/media/files/yolov3.weights
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 248007048 (237M) [application/octet-stream]
# Saving to: ‘yolov3.weights.1’
#
# yolov3.weights.1     57%[==========>         ] 135.76M  62.8KB/s    eta 20m 57s^C

# %%
# Out:
# --2020-05-27 13:53:30--  https://github.com/VishalChak/yolov3.git
# Resolving github.com (github.com)... 192.30.255.113
# Connecting to github.com (github.com)|192.30.255.113|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://github.com/VishalChak/yolov3 [following]
# --2020-05-27 13:53:30--  https://github.com/VishalChak/yolov3
# Reusing existing connection to github.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘yolov3.git’
#
# yolov3.git              [ <=>                ] 119.30K  --.-KB/s    in 0.03s
#
# 2020-05-27 13:53:31 (4.49 MB/s) - ‘yolov3.git’ saved [122163]

# %%
# !git clone https://github.com/VishalChak/yolov3.git
# Out:
# fatal: destination path 'yolov3' already exists and is not an empty directory.

# %%
# !git clone https://github.com/ultralytics/yolov3.git
# Out:
# Cloning into 'yolov3'...
# remote: Enumerating objects: 16, done.
# remote: Counting objects: 100% (16/16), done.
# remote: Compressing objects: 100% (12/12), done.
# remote: Total 9219 (delta 6), reused 11 (delta 4), pack-reused 9203
# Receiving objects: 100% (9219/9219), 7.15 MiB | 2.96 MiB/s, done.
# Resolving deltas: 100% (6346/6346), done.

# %%
# %cd yolov3/

# %%
# !ls

# %%
# !pip install -r requirements.txt

# %%
# !ls
# Out:
# drive  gdrive  sample_data  yolov3

# %%
# %cd /content/yolov3/
# Out:
# /content/yolov3

# %%
# !python detect.py --source /content/drive/"My Drive"/21_05_08_09 --save-txt --output /content/drive/"My Drive"/08_09_txt/
# Out:
# Namespace(agnostic_nms=False, augment=False, cfg='./cfg/yolov3-spp.cfg', classes=None, conf_thres=0.3, device='', fourcc='mp4v', half=False, img_size=512, iou_thres=0.6, names='./data/coco.names', output='/content/drive/My Drive/08_09_txt/', save_txt=True, source='/content/drive/My Drive/21_05_08_09', view_img=False, weights='weights/yolov3-spp-ultralytics.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla T4', total_memory=15079MB)
#
# Model Summary: 225 layers, 6.29987e+07 parameters, 6.29987e+07 gradients
# image 1/170 /content/drive/My Drive/21_05_08_09/T21_05_08_091760.jpg: 320x512 5 persons, 1 cars, 1 motorcycles, 1 tvs, Done. (0.033s)
# image 2/170 /content/drive/My Drive/21_05_08_09/T21_05_08_091780.jpg: 320x512 5 persons, 1 cars, 1 motorcycles, Done. (0.032s)
# image 3/170 /content/drive/My Drive/21_05_08_09/T21_05_08_091800.jpg: 320x512 5 persons, 1 cars, 2 motorcycles, Done. (0.032s)
# ...

# %%
# !zip txt.zip /content/yolov3/output
# Out:
#   adding: content/yolov3/output/ (stored 0%)

# %%
# %cd /content/yolov3/output
# Out:
# /content/yolov3/output

# %%
# I have created a zip file:

# !zip -r /content/file.zip /content/yolov3/output/
# Out:
#   adding: content/yolov3/output/ (stored 0%)
#   adding: content/yolov3/output/22_05_12_1740120.txt (deflated 49%)
#   adding: content/yolov3/output/22_05_12_1740660.txt (deflated 38%)
#   adding: content/yolov3/output/22_05_12_1739900.txt (deflated 49%)
#   adding: content/yolov3/output/22_05_12_1740020.txt (deflated 48%)
#   adding: content/yolov3/output/22_05_12_1740180.jpg (deflated 1%)
#   adding: content/yolov3/output/22_05_12_1740140.txt (deflated 50%)
#   adding: content/yolov3/output/22_05_12_1740000.txt (deflated 51%)
#   adding: content/yolov3/output/22_05_12_1740960.jpg (deflated 1%)
#   adding: content/yolov3/output/22_05_12_1740540.jpg (deflated 1%)
#   adding: content/yolov3/output/22_05_12_1740740.txt (deflated 50%)
#   adding: content/yolov3/output/22_05_12_1740020.jpg (deflated 2%)
#   adding: content/yolov3/output/22_05_12_1740040.jpg (deflated 1%)
#   adding: content/yolov3/output/bus.txt (deflated 37%)
# ...
